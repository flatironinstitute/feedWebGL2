# %% [markdown]
# # Final Thoughts
#
# ## The WebGL2 feedback can implement highly parallel computations.
#
# ## Feedback programs can be created and controlled by Jupyter widget interfaces.
#
# ## Note: the Tensorflow.js project uses WebGL feedback to implement parallel tensor operations.
#
# ## The Instanced Feedback mechanism is suitable for many problems with
#
# ## -- Highly parallel components that don't need to communicate.
# ## -- Few-ish inputs (inputs can also be from a small number of large matrices -- textures)
# ## -- Very few outputs
# ## -- Vector or Rectangular structure
#
# # Each processor sees this:

# %%
import feedback_diagrams
feedback_diagrams.stage1()
# Out:
# <style>.container { width:100% !important; }</style>
# DualCanvasWidget(status='deferring flush until render')

# %% [markdown]
# # The whole architecture looks like this:

# %%
feedback_diagrams.feedback_architecture()
# Out:
# DualCanvasWidget(status='deferring flush until render')

# %% [markdown]
# # A lot of interesting problems fit into this structure
#
# ## -- Matrix multiplication (implemented)
# ## -- Gauss Jordan reduction (...working, can be used for:)
# ## -- Matrix inversion
# ## -- Linear programming (simplex method and others)
# ## -- Other optimization algorithms
# ## -- Graph force directed layout
# ## -- Particle system simulations
# ## -- ... and many more

# %% [markdown]
# # Bonus material, if time permits:
#
#
# <h2><a href="https://github.com/flatironinstitute/radiation_viz">Black hole radiative pressure
#     -- simulation data by Yan-Fei Jiang</a>
#     <br>VIDEO: on my computer only file:///Users/awatters/tmp/images/rho10fps.webm
#     </h2>
#
# <h2><a href="https://github.com/flatironinstitute/Fermi_surface_visualization">
#     Crystal lattice electron energy Fermi surfaces
#     -- theoretical data generated by Manuel Zingl and others
# </a></h2>
