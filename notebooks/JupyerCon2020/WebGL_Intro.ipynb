# %% [markdown]
# # WebGL is amazing
#
# ## <a href="https://www.zygotebody.com/">Look at https://www.zygotebody.com/ for example.</a>

# %% [markdown]
# # WebGL2 Outline
#
# <h2>
#     WebGL2 is browser functionality for processing graphics in parallel on the GPU.
#     </h2>
#
# <img src="./rasterization.png">
#
# <a href="https://www.willusher.io/webgl/2019/01/13/volume-rendering-with-webgl">
#     https://www.willusher.io/webgl/2019/01/13/volume-rendering-with-webgl</a>

# %% [markdown]
# <h2>A WebGL2 Scene typically processes millions of vertices and pixels on thousands of GPU processors instantaneously</h2>
#
# <h2>The programmer can only change the shaders, which are restricted to straight line code with few inputs and fewer outputs</h2>

# %% [markdown]
# <h2>A simple example vertex shader</h2>
#
# ```C
# #version 410
#
# layout (std140) uniform Matrices {
#     mat4 projModelViewMatrix;
#     mat3 normalMatrix;
# };
#
# in vec3 position;
# in vec3 normal;
# in vec2 texCoord;
#
# out VertexData {
#     vec2 texCoord;
#     vec3 normal;
# } VertexOut;
#
# void main()
# {
#     VertexOut.texCoord = texCoord;
#     VertexOut.normal = normalize(normalMatrix * normal);
#     gl_Position = projModelViewMatrix * vec4(position, 1.0);
# }
# ```
#
# <a href="https://www.lighthouse3d.com/tutorials/glsl-tutorial/vertex-shader/">
#     https://www.lighthouse3d.com/tutorials/glsl-tutorial/vertex-shader/</a>
#
# <h2>Even though it is simple, this shader specifies how to broadcast a matrix multiplication transformation and vector normalization to millions of vertices in parallel</h2>

# %% [markdown]
# <hr><hr>
#
# # *Basic WebGL:* Single instance/multiple vertices
# # How to rotate a chimp
#
# ## First you need to take your chimp and represent it using a "mesh" of triangle vertices -- possibly millions of vertices
#
# <table border>
#     <tr> <th style="background-color:pink">Chimp</th> <th>Chimp Mesh</th></tr>
#     <tr> <td><img src="monkey_transparent.png" width="200"/></td> <td><img src="monkey_mesh.jpg"/></td> </tr>
#     </table>
#
# <a href="http://www.digiteck3d.com/3d-art/3d-work-personal/look-dev/">
#     http://www.digiteck3d.com/3d-art/3d-work-personal/look-dev/</a>
#
# <h2>Load the chimp vertices into the GPU WebGL program state</h2>
#
# <h2>Run the rendering pipeline.</h2>
#
# <h2>The vertex processing stage broadcasts the matrix tranformation rotation to all vertices of the chimp in parallel</h2>

# %%
import feedback_diagrams
feedback_diagrams.widen_notebook()
feedback_diagrams.rotation_pipeline()
# Out:
# <style>.container { width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>
# DualCanvasWidget(status='deferring flush until render')

# %% [markdown]
# <h2>To rotate the chimp: change <b>only the matrix</b> and run the processing pipeline again</h2>
#
# ### As many times as you like -- all vertices and downstream pixels rotate instantaneously.  The "local attribute" vertices are already on the GPU...
#
#
# <hr><hr>
#
# # *WebGL Instancing:* Multiple instances/multiple vertices
# # How to make lots of chimps at different locations
#
# <img src="monkey_instances.jpg"/>
#
# <h2>Define the chimp mesh <em>ONCE</em></h2>
#
# <h2>Use Instanced rendering to draw the mesh many times at different positions</h2>
#
# <h3>Instanced programs have two types of "local" attributes</h3>
# <h3>-- "Per instance" position differs for each chimp (left column).</h3>
# <h3>-- "Per mesh" vertex is used in every chimp (top row).</h3>

# %%
feedback_diagrams.instance_pipeline()
# Out:
# DualCanvasWidget(status='deferring flush until render')

# %% [markdown]
# <hr><hr>
#
# # We want to generate isosurfaces, not chimps.
#
#
# # Instead of chimps we will be interested in matrix entries (voxels)
#
# # Each voxel will be broken into 6 tetrahedra with 2 triangles each with 3 vertices in each triangle

# %%
feedback_diagrams.voxel_grid_html()
# Out:
# <style>
#
# .voxelsgrid {
#     display: grid;
#     grid-template-columns:  auto auto auto auto auto auto auto auto auto auto auto auto auto auto auto auto auto auto auto auto auto auto auto auto auto auto auto auto auto auto auto auto auto auto auto auto auto;
#     grid-gap: 10px;
# }
#
# </style>
# <div class="voxelsgrid">
# <div style="background-color: white; grid-row: 1; grid-column: 1">tet</div>
# <div style="background-color: pink; grid-row: 1; grid-column: 2 / span 6">tetrahedron 0</div>
# <div style="background-color: pink; grid-row: 1; grid-column: 8 / span 6">tetrahedron 1</div>
# <div style="background-color: pink; grid-row: 1; grid-column: 14 / span 6">tetrahedron 2</div>
# <div style="background-color: pink; grid-row: 1; grid-column: 20 / span 6">tetrahedron 3</div>
# <div style="background-color: pink; grid-row: 1; grid-column: 26 / span 6">tetrahedron 4</div>
# <div style="background-color: pink; grid-row: 1; grid-column: 32 / span 6">tetrahedron 5</div>
# <div style="background-color: white; grid-row: 2; grid-column: 1">tri</div>
# <div style="background-color: salmon; grid-row: 2; grid-column: 2 / span 3">triangle0:0</div>
# <div style="background-color: salmon; grid-row: 2; grid-column: 5 / span 3">triangle0:1</div>
# <div style="background-color: salmon; grid-row: 2; grid-column: 8 / span 3">triangle1:0</div>
# <div style="background-color: salmon; grid-row: 2; grid-column: 11 / span 3">triangle1:1</div>
# <div style="background-color: salmon; grid-row: 2; grid-column: 14 / span 3">triangle2:0</div>
# <div style="background-color: salmon; grid-row: 2; grid-column: 17 / span 3">triangle2:1</div>
# <div style="background-color: salmon; grid-row: 2; grid-column: 20 / span 3">triangle3:0</div>
# <div style="background-color: salmon; grid-row: 2; grid-column: 23 / span 3">triangle3:1</div>
# <div style="background-color: salmon; grid-row: 2; grid-column: 26 / span 3">triangle4:0</div>
# <div style="background-color: salmon; grid-row: 2; grid-column: 29 / span 3">triangle4:1</div>
# <div style="background-color: salmon; grid-row: 2; grid-column: 32 / span 3">triangle5:0</div>
# <div style="background-color: salmon; grid-row: 2; grid-column: 35 / span 3">triangle5:1</div>
# <div style="background-color: white; grid-row: 3; grid-column: 1">v</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 2">V0:0:0</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 3">V0:0:1</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 4">V0:0:2</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 5">V0:1:0</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 6">V0:1:1</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 7">V0:1:2</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 8">V1:0:0</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 9">V1:0:1</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 10">V1:0:2</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 11">V1:1:0</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 12">V1:1:1</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 13">V1:1:2</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 14">V2:0:0</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 15">V2:0:1</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 16">V2:0:2</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 17">V2:1:0</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 18">V2:1:1</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 19">V2:1:2</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 20">V3:0:0</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 21">V3:0:1</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 22">V3:0:2</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 23">V3:1:0</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 24">V3:1:1</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 25">V3:1:2</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 26">V4:0:0</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 27">V4:0:1</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 28">V4:0:2</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 29">V4:1:0</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 30">V4:1:1</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 31">V4:1:2</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 32">V5:0:0</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 33">V5:0:1</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 34">V5:0:2</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 35">V5:1:0</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 36">V5:1:1</div>
# <div style="background-color: #fee; grid-row: 3; grid-column: 37">V5:1:2</div>
# <div style="background-color: pink; grid-row: 4; grid-column: 1">C0</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 2">V0:0:0</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 3">V0:0:1</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 4">V0:0:2</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 5">V0:1:0</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 6">V0:1:1</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 7">V0:1:2</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 8">V1:0:0</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 9">V1:0:1</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 10">V1:0:2</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 11">V1:1:0</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 12">V1:1:1</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 13">V1:1:2</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 14">V2:0:0</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 15">V2:0:1</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 16">V2:0:2</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 17">V2:1:0</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 18">V2:1:1</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 19">V2:1:2</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 20">V3:0:0</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 21">V3:0:1</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 22">V3:0:2</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 23">V3:1:0</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 24">V3:1:1</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 25">V3:1:2</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 26">V4:0:0</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 27">V4:0:1</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 28">V4:0:2</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 29">V4:1:0</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 30">V4:1:1</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 31">V4:1:2</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 32">V5:0:0</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 33">V5:0:1</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 34">V5:0:2</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 35">V5:1:0</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 36">V5:1:1</div>
# <div style="background-color: #afa; grid-row: 4; grid-column: 37">V5:1:2</div>
# <div style

# %% [markdown]
# ## The tetrahedra, triangles, vertices are generated by the "Marching Tetrahedra" pipeline described later
#
#
# # ... But first let's talk about WebGL feedback
